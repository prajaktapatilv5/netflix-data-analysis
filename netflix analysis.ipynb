# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns # type: ignore


data = {
    'Date': ['2021','2022','2019','2021','2022','2019'],
    'Title': ['spideran','noexit','Encanto','spideran','spideran','batman'],
    'popularity':[5083,3827,2402,5076,1793,1057],
    'vote_count':[8940,1151,122,5076,1793,1051],
    'vote_avg':['popular','popular','below_avg','avg','avg','avg'],
    'genre':['action','crime','sicence','thirreler','animation','adventure']
}

df = pd.DataFrame(data)
print(df)

df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.year 
df['Date'].dtypes


def catigorize_col (df, col, labels):
  edges = [df[col].describe()['min'],
  df[col].describe()['25%'],
  df[col].describe()['50%'],
  df[col].describe()['75%'],
  df[col].describe()['max']
  ]
  df[col] = pd.cut(df[col], edges, labels = labels, duplicates='drop')
  return df


df['vote_avg'].value_counts()


df.dropna(inplace = True)
# confirming
df.isna().sum()


df['genre'] = df['genre'].str.split(', ')
df = df.explode('genre').reset_index(drop=True)
df.head()

df['genre'] = df['genre'].astype('category')
# confirming changes
df['genre'].dtypes

df.nunique()


sns.set_style('whitegrid')

df['genre'].describe()


sns.catplot(y = 'genre', data = df, kind = 'count',
order = df['genre'].value_counts().index,
color = '#4287f5')
plt.title('genre column distribution')
plt.show()



sns.catplot(y = 'vote_avg', data = df, kind = 'count',
order = df['vote_avg'].value_counts().index,
color = '#4287f5')
plt.title('votes destribution')
plt.show()



df[df['Popularity'] == df['Popularity'].max()]


df['Release_Date'].hist()
plt.title('Release_Date column distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import seaborn as sns # type: ignore
#       7 data = {
#       8     'Date': ['2021','2022','2019','2021','2022','2019'],
#       9     'Title': ['spideran','noexit','Encanto','spideran','spideran','batman'],
#    (...)
#      13     'genre':['action','crime','sicence','thirreler','animation','adventure']
#      14 }
#      16 df = pd.DataFrame(data)
#
# ModuleNotFoundError: No module named 'seaborn'
